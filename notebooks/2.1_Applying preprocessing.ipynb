# %%
import pandas as pd

# %%
raw_data = pd.read_csv('data/train.csv')
raw_data.head()
# Out:
#    tweet_id                                              tweet  sentiment
# 0      1701  #sxswnui #sxsw #apple defining language of tou...          1
# 1      1851  Learning ab Google doodles! All doodles should...          1
# 2      2689  one of the most in-your-face ex. of stealing t...          2
# 3      4525  This iPhone #SXSW app would b pretty awesome i...          0
# 4      3604  Line outside the Apple store in Austin waiting...          1

# %%
raw_data.dropna(inplace=True)

# %%
# !pip install -U preprocessing
# Out:
# Requirement already satisfied: preprocessing in c:\users\ashup\miniconda3\lib\site-packages (0.1.13)
# Requirement already satisfied: nltk==3.2.4 in c:\users\ashup\miniconda3\lib\site-packages (from preprocessing) (3.2.4)
# Requirement already satisfied: sphinx-rtd-theme==0.2.4 in c:\users\ashup\miniconda3\lib\site-packages (from preprocessing) (0.2.4)
# Requirement already satisfied: six in c:\users\ashup\miniconda3\lib\site-packages (from nltk==3.2.4->preprocessing) (1.15.0)

# %%
#import preprocessing.text as ptext
from preprocessing.text import keyword_tokenize, remove_unbound_punct, remove_urls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-fcea3e93cbba> in <module>
#       1 #import preprocessing.text as ptext
# ----> 2 from preprocessing.text import keyword_tokenize, remove_unbound_punct, remove_urls
#
# ~\Miniconda3\lib\site-packages\preprocessing\text.py in <module>
#       5
#       6 from preprocessing.errors import FunctionError, InputError
# ----> 7 import preprocessing.spellcheck as spellcheck
#       8
#       9 import html
#
# ~\Miniconda3\lib\site-packages\preprocessing\spellcheck.py in <module>
#      12
#      13 EN_ALPHABET = 'abcdefghijklmnopqrstuvwxyz'
# ---> 14 WORD_DISTRIBUTION = Counter(re.findall(r'\w+', open(path.join(path.dirname(__file__), 'data/bnc_wiktionary_corpus.txt')).read().lower()))
#      15
#      16
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ashup\\Miniconda3\\lib\\site-packages\\preprocessing\\data/bnc_wiktionary_corpus.txt'

# %%
processed_data = preprocess_text(raw_data, 'tweet')

# %%
processed_data.head(10)
# Out:
#    tweet_id                                              tweet  sentiment
# 0      1701  sxswnui sxsw appl defin languag touch differ d...          1
# 1      1851  learn googl doodl doodl light funni innov exce...          1
# 2      2689  one in-your-fac ex steal show yr rt sxsw appl ...          2
# 3      4525  iphon sxsw app would b pretti awesom crash eve...          0
# 4      3604  line outsid appl store austin wait new ipad sx...          1
# 5       966  technew one lone dude await ipad 2 appleûª sx...          1
# 6      1395  sxsw tip princ npr video toy shop zuckerberg l...          1
# 7      8182  nu user rt new ubersoci iphon app store includ...          1
# 8      8835                free sxsw sampler itun link freemus          2
# 9       883  think might go weekend without see ipad case t...          2

# %%
def remove_specialchars(tweet):
    tweet=tweet.encode('utf-8')
    tweet=re.sub(rb'[^\x00-\x7f]',rb' ',tweet)
    tweet.decode('utf-8')

# %%
processed_data['tweet'] = processed_data['tweet'].apply(lambda x: ''.join([i if ord(i) < 128 else ' ' for i in x]))

# %%
processed_data.head(20)
# Out:
#     tweet_id                                              tweet  sentiment
# 0       1701  sxswnui sxsw appl defin languag touch differ d...          1
# 1       1851  learn googl doodl doodl light funni innov exce...          1
# 2       2689  one in-your-fac ex steal show yr rt sxsw appl ...          2
# 3       4525  iphon sxsw app would b pretti awesom crash eve...          0
# 4       3604  line outsid appl store austin wait new ipad sx...          1
# 5        966  technew one lone dude await ipad 2 apple    sx...          1
# 6       1395  sxsw tip princ npr video toy shop zuckerberg l...          1
# 7       8182  nu user rt new ubersoci iphon app store includ...          1
# 8       8835                free sxsw sampler itun link freemus          2
# 9        883  think might go weekend without see ipad case t...          2
# 10      6398  rt offici sxsw app    sxsw go    bit.ly/hmiiga...          3
# 11      2369                       offici 'm buy ipad sxsw elev          2
# 12      3944      're give away ipad 2 x box book sxsw techenvi          2
# 13      6909  rt 're offici sxsw come grill mention us w/ za...          1
# 14      7917  compani watch sxsw trade show floor link app f...          1
# 15      5849  rt googl marissa mayer futur locat augment rea...          1
# 16      1955  dl calyp app get calyp casa sxsw free mobil ap...          1
# 17      1472  well yeah music iphon nerd rt god cute girl ev...          2
# 18      4730  appl open pop store sxsw link via appl ipad2 t...          1
# 19      2166                     atleast sxsw 'm ipad doublelos          1
